# %% [markdown]
# #### Working With File Paths
# When working with files in Python, handling file paths correctly is crucial to ensure your code works across different operating systems and environments. Python provides several modules and functions for working with file paths effectively.

# %%
import os 
cwd=os.getcwd()
print(f'current working directory id {cwd}')
# Out:
# current working directory id d:\Udemy\Complete-Python-Bootcamp-main\6-File Handling

# %%
## creating a new directory 

new_dir="package"
os.mkdir(new_dir)
print(f"directory '{new_dir}' created" )
# Out:
# directory 'package' created

# %%
## listing files and directories 
item=os.listdir('.')
print(item)
# Out:
# ['6.1-fileoperation.ipynb', '6.2-filepath.ipynb', 'destination_file', 'destination_file.txt', 'example.bin', 'example.txt', 'fileoperation.ipynb', 'package']

# %%
## joining paths 

dir_name="folder"
file_name="file.txt"
full_path=os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
dir_name="folder"
file_name="file.txt"
full_path=os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# d:\Udemy\Complete-Python-Bootcamp-main\6-File Handling\folder\file.txt

# %%
path = 'example1.txt'
if os.path.exists(path):
    print(f"the path '{path}' exists")
else:
    print(f"the path '{path}' not here")
# Out:
# the path 'example1.txt' not here

# %%
## checking if a path is a file or directory 

import os 

path='example.txt'
if os.path.isfile(path):
    print("is a file")
elif os.path.isdir(path):
    print("is a dir")
else:
    print("nothing ")
# Out:
# is a file

# %%
## getting the absolute path 

rel_path='example.txt'
abs_path=os.path.abspath(rel_path)
print(abs_path)
# Out:
# d:\Udemy\Complete-Python-Bootcamp-main\6-File Handling\example.txt
