# %% [markdown]
# #### Understanding Exceptions
#
# Exception handling in Python allows you to handle errors gracefully and take corrective actions without stopping the execution of the program. This lesson will cover the basics of exceptions, including how to use try, except, else, and finally blocks.

# %% [markdown]
# ##### What Are Exceptions?
# Exceptions are events that disrupt the normal flow of a program. They occur when an error is encountered during program execution. Common exceptions include:
#
# - ZeroDivisionError: Dividing by zero.
# - FileNotFoundError: File not found.
# - ValueError: Invalid value.
# - TypeError: Invalid type.

# %%
## exception try , except block

try:
    a=b
except :
    print("name error , enter correct name ")
# Out:
# name error , enter correct name

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
try:
    a=b
except NameError as er:
    print(er)
# Out:
# name 'b' is not defined

# %%
try:
    result=10/0
except ZeroDivisionError as ex:
    print(ex)
    print('enter number greater than zero')
# Out:
# division by zero
# enter number greater than zero

# %%
try:
    result=1/2
    a=b
except ZeroDivisionError as ex:
    print(ex)
    print('enter number greater than zero')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 try:
#       2     result=1/2
# ----> 3     a=b
#       4 except ZeroDivisionError as ex:
#       5     print(ex)
#
# NameError: name 'b' is not defined

# %%
try:
    result=1/2
    a=b
except ZeroDivisionError as ex:
    print(ex)
    print('enter number greater than zero')
except Exception as ex1:
    print(ex1)
    print('main exception got caught here ')
# Out:
# name 'b' is not defined
# main exception got caught here

# %%
try:
    num=int(input('enter a number : '))
    result=10/num 
except ValueError as vr:
    print('enter valid number ')
except ZeroDivisionError :
    print('enter num grater than 0 ')
except Exception as ex:
    print(ex)
print(result)
# Out:
# 0.8333333333333334

# %% [markdown]
# if try condition is true then only the else will run
#
# other wise the error only display

# %%
## try , except , else block 

try:
    num=int(input('Enter a number: '))
    result=10/num
except ValueError:
    print('in valid number ')
except ZeroDivisionError:
    print('cant divide by zero ')
except Exception as ex:
    print(ex)

else:
    print('the result is ',result)
# Out:
# cant divide by zero

# %% [markdown]
# in finally -- it will run every time weather the trty is true or false

# %%
## try , except ,else and finally 

try:
    num=int(input('Enter a number: '))
    result=10/num
except ValueError:
    print('in valid number ')
except ZeroDivisionError:
    print('cant divide by zero ')
except Exception as ex:
    print(ex)

else:
    print('the result is ',result)

finally:
    print('execution complete')

# %%
## file handlilng and exception handling 

try :
    file=open('example.txt','r')
    content=file.read()
    print(content)

except FileNotFoundError:
    print('the file does not exists')

finally:
    if 'file' in locals() and not file.closed():
        file.close()
        print('file close ')
# Out:
# the file does not exists
