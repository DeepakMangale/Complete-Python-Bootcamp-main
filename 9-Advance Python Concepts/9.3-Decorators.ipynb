# %% [markdown]
# #### Decorators
# Decorators are a powerful and flexible feature in Python that allows you to modify the behavior of a function or class method. They are commonly used to add functionality to functions or methods without modifying their actual code. This lesson covers the basics of decorators, including how to create and use them.

# %%
## function copy
## closures
## decorators

# %%
## function copy
def welcome():
    return "welcome to the course"

welcome()
# Out:
# 'welcome to the course'

# %%
wel=welcome
print(wel())

del welcome
print(wel())
# Out:
# welcome to the course
# welcome to the course

# %%
## closures


def main_welcome(msg):
    
    def sub_welcome_method():
        print("welcome to the course ")
        print(msg)
        print("pls learn these concept")
    
    return sub_welcome_method()

# %%
main_welcome("welcome everyone")
# Out:
# welcome to the course
# welcome everyone
# pls learn these concept

# %%
def main_welcome(func):
    
    def sub_welcome_method():
        print("welcome to the course ")
        func("func will print")
        print("pls learn these concept")
    
    return sub_welcome_method()

# %%
main_welcome(print)
# Out:
# welcome to the course
# func will print
# pls learn these concept

# %%
def main_welcome(func,lst):
    
    def sub_welcome_method():
        print("welcome to the course ")
        print(func(lst))
        print("learn concept")
    
    return sub_welcome_method()

# %%
main_welcome(len,[1,2,3,4,5])
# Out:
# welcome to the course
# 5
# learn concept

# %%
len([1,2,3,4,5,6,7])
# Out:
# 7

# %%
### Decorator
def main_welcome(func):
   
    def sub_welcome_method():
        print("Welcome to the advance python course")
        func()
        print("Please learn these concepts properly")
    return sub_welcome_method()

# %%
def course_introduction():
    print("this is an advance pyhton course")
course_introduction()
# Out:
# this is an advance pyhton course

# %%
main_welcome(course_introduction)
# Out:
# Welcome to the advance python course
# this is an advance pyhton course
# Please learn these concepts properly

# %%
@main_welcome
def course_introduction():
    print("this is an advance pyhton course")
# Out:
# Welcome to the advance python course
# this is an advance pyhton course
# Please learn these concepts properly

# %%
def my_decorator(fun):
    def wrapper():
        print("something is happening before the fun called")
        fun()
        print("something is happening after the function called")
    return wrapper

# %%
@my_decorator
def say_hello():
    print("hello")

# %%
say_hello()
# Out:
# something is happening before the fun called
# hello
# something is happening after the function called

# %%
## decorators with arguments

def repeat(n):
    def decorator(fun):
        def wrapper(*arg, **kwargs):  # argument , key word argument
            for _ in range(n):
                fun(*arg, **kwargs)
        return wrapper
    return decorator

# %%
@repeat(4)
def say_hello():
    print("Hello")

# %%
say_hello()
# Out:
# Hello
# Hello
# Hello
# Hello
