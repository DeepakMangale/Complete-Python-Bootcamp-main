# %% [markdown]
# #### Real-World Examples Using Lists in Python
# Lists are one of the most commonly used data structures in Python, thanks to their versatility and ease of use. Here are several practical examples that illustrate their use in real-world scenarios

# %% [markdown]
# ##### Example 1. Manage A To Do List
# - Create a To Do List To Keep Track OF Tasks

# %%
to_do_list=["clean the house","buy things","pay bills"]

to_do_list.append("do meeting")
to_do_list.append("go for a run")

to_do_list.remove("clean the house")

if "pay bills" in to_do_list:
    print("don't forget to pay the bills")

print("list to do")
for task in to_do_list:
    print(f"- {task}")
# Out:
# don't forget to pay the bills
# list to do
# - buy things
# - pay bills
# - do meeting
# - go for a run

# %% [markdown]
# ##### Example 2: Organizing Student Grades
# - Create a list to store and calculate average grades for students

# %% [markdown]
# ##### Example 3: Managing An Inventory
# - Use a list to manage inventory items in a store

# %%
inv=["apple","banana","orange","grapes","kiwi"]
inv.append("straberrey")
inv.remove("kiwi")

item="apple"
if item in inv:
    print(f"{item} is in stock")
else:
    print(f"{item} is out of stock")

print("list of fruits")
for item in inv:
    print(f"-{item}")
# Out:
# apple is in stock
# list of fruits
# -apple
# -banana
# -orange
# -grapes
# -straberrey

# %% [markdown]
# ##### Example 4:Collecting User Feedback
# - Use a list to collect and analyze user feedback.
