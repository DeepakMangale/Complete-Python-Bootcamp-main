# %% [markdown]
# #### Functions in Python
# Video Outline:
# 1. Introduction to Functions
# 2. Defining Functions
# 3. Calling Functions
# 4. Function Parameters
# 5. Default Parameters
# 6. Variable-Length Arguments
# 7. Return Statement

# %% [markdown]
# ##### Introduction to Functions
# Definition:
#
# A function is a block of code that performs a specific task.
# Functions help in organizing code, reusing code, and improving readability.

# %%
## syntax
def function_name(parameters):
    """Docstring"""
    # Function body
    return expression

# %%
## without function 
# why function 

num = 24
if num%2==0:
    print("the number is even")
else:
    print("the number is odd")
# Out:
# the number is even

# %%
## function to check the number is even or odd

def check(num):
    if num%2==0:
        print(f" num {num} is even")
    else:
        print(f" num {num} is odd")
check(24)
# Out:
#  num 24 is even

# %%
## function to add 2 numbers 

def add(a,b):
    return a+b
addition=add(4,4)
print(addition)
# Out:
# 8

# %%
## default parameters 

def wel (name):
    print(f"hello {name} welcome to the page ")

wel("sumit")
# Out:
# hello sumit welcome to the page

# %%
## name = guest is a default parameter
def wel (name="guest"):
    print(f"hello {name} welcome to the page ")

wel()  ## if we didnt give any parameter then default will print
# Out:
# hello guest welcome to the page

# %%
## variable length arguments 
## positional and keywords arguments

def print_number(*args):
    for numbers in args:
        print(numbers)

# %%
print_number(1,2,3,4,"sumit")
# Out:
# 1
# 2
# 3
# 4
# sumit

# %%
## keywords arguments 

def print_details(**kval):
    for key,value in kval.items():
        print(f"{key}:{value}")

# %%
print_details(name="sumit",age="22",cuntry="india")
# Out:
# name:sumit
# age:22
# cuntry:india

# %%
def print_details(*args,**kval):

    for val in args:
        print(val)
    
    for key,value in kval.items():
        print(f"{key}:{value}")

# %%
print_details(1,2,3,4,"sumit",name="deepak",ages="22",country="india")
# Out:
# 1
# 2
# 3
# 4
# sumit
# name:deepak
# ages:22
# country:india
